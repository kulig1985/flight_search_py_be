# %%
import inspect
import sys
import os
from datetime import datetime
import pandas as pd
import time
from functools import reduce
import logging
from dateutil.relativedelta import relativedelta
from tables import NaturalNameWarning
import warnings
warnings.filterwarnings('ignore', category=NaturalNameWarning)
sys.path.insert(0, os.path.dirname(os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))))
from swagger_client.api.default_api import DefaultApi
from configparser import ConfigParser
import smtplib
from email.message import EmailMessage
import shutil
import platform
import requests
from model.flight_result_model import *
import numpy as np
from sqlalchemy import create_engine

# %%
def load_config():
    try:
        log.info("Config file load begin")
        config = ConfigParser()
        if platform.platform()[:platform.platform().index('-')].lower() == 'macos':
            config_path = '/Users/kuligabor/Documents/KIWI/flight_search_py_be/kiwi.cfg'
        else:
            config_path = '/data/flight/flight_search_py_be/kiwi.cfg'
        config.read(config_path, encoding='utf-8')
        log.info("Config file load end")
        return config

    except Exception as e:
        log.error("Config file load error: {}".format(str(e)))
        sys.exit(1)

def load_logger():

    try:
        log = logging.getLogger('LOG')
        log.setLevel(logging.DEBUG)
        fh = logging.FileHandler('fligh_runner.log', encoding="utf-8")
        fh.setLevel(logging.DEBUG)

        ch = logging.StreamHandler()
        ch.setLevel(logging.DEBUG)

        formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s', datefmt='%Y-%m-%d %H:%M:%S')
        ch.setFormatter(formatter)
        fh.setFormatter(formatter)

        log.addHandler(ch)
        log.addHandler(fh)
        log.info('Logger set')

        return log

    except Exception as e:
        print("logger error: " + str(e))
        sys.exit(1)

# %%
log = load_logger()
config = load_config()

date_from = config.get('BASE', "date_from")
date_to = config.get('BASE', "date_to")
nights_in_dst_from = config.get('BASE', "nights_in_dst_from")
nights_in_dst_to = config.get('BASE', "nights_in_dst_to")
max_stopovers = int(config.get('BASE', "max_stopovers"))
adults = int(config.get('BASE', "adults"))
children = int(config.get('BASE', "children"))
infants = int(config.get('BASE', "infants"))
adult_hold_bag = config.get('BASE', "adult_hold_bag")
adult_hand_bag = config.get('BASE', "adult_hand_bag")
child_hand_bag = config.get('BASE', "child_hand_bag")
airports = config.get('BASE', "airports")
h5_store_name = config.get('BASE', "h5_store_name")
h5_api_name = config.get('BASE', "h5_api_name")
result_dir = config.get('BASE', 'result_dir')
api_key = config.get('BASE', 'api_key')
# Out:
# 2023-03-11 14:13:28 - INFO - Logger set
# 2023-03-11 14:13:28 - INFO - Config file load begin
# 2023-03-11 14:13:28 - INFO - Config file load end

# %%
airports
# Out:
# 'TIA,EVN,GRZ,INN,KLU,LNZ,SZG,VIE,GYD,MSQ,ANR,BRU,CRL,LGG,OST,SJJ,TZL,BOJ,SOF,VAR,DBV,PUY,SPU,ZAD,ZAG,LCA,PFO,BRQ,PRG,AAL,AAR,BLL,CPH,FAE,TLL,HEL,OUL,RVN,TMP,TKU,VAA,AJA,BIA,EGC,BIQ,BOD,BES,FSC,LIL,LYS,MRS,MPL,NTE,NCE,BVA,CDG,ORY,SXB,RNS,RUN,TLN,TLS,KUT,TBS,FMM,BER,SXF,TXL,BRE,CGN,DTM,DRS,DUS,FRA,HHN,FDH,HAM,HAJ,FKB,LEJ,MUC,FMO,NUE,PAD,STR,NRN,ATH,CHQ,CFU,HER,KGS,JMK,RHO,JTR,SKG,ZTH,BUD,DEB,KEF,ORK,DUB,NOC,KIR,SNN,AHO,AOI,BRI,BGY,BLQ,BDS,CAG,CTA,CIY,FLR,GOA,SUF,LIN,MXP,NAP,OLB,PMO,PEG,PSR,PSA,CIA,FCO,TPS,TSF,TRN,VCE,VRN,ALA,TSE,PRN,RIX,KUN,VNO,LUX,MLA,KIV,TGD,TIV,AMS,EIN,GRQ,MST,RTM,SKP,AES,BGO,BOO,HAU,KRS,OSL,TRF,SVG,TOS,TRD,GDN,KTW,KRK,POZ,SZZ,WAW,WMI,WRO,FAO,LIS,FNC,PDL,OPO,OTP,CLJ,IAS,TSR,SVX,KRR,DME,SVO,VKO,ZIA,OVB,LED,AER,BEG,INI,BTS,KSC,LJU,ALC,LEI,OVD,BCN,BIO,FUE,GRO,LPA,GRX,IBZ,XRY,SPC,ACE,MAD,AGP,MAH,PMI,RMU,REU,SDR,SCQ,SVQ,TFN,TFS,VLC,ZAZ,GOT,MMX,ARN,BMA,NYO,VST,BSL,BRN,GVA,ZRH,ADA,ESB,AYT,DLM,IST,SAW,ADB,BJV,TZX,HRK,KBP,IEV,LWO,ODS,ABZ,BHD,BFS,BHX,BRS,CWL,DSA,EMA,EDI,EXT,GLA,PIK,HUY,JER,LBA,LPL,LCY,LGW,LHR,LTN,SEN,STN,MAN,NCL,SOU'

# %%
def get_data_from_api():

    log.info('get_data_from_api started!')

    api = DefaultApi()

    airports_list = airports.split(',')

    flight_result_list = []
    
    #log.debug(airports_list)

    for airport in airports_list:

        log.debug(f'Checking BUD to {airport}')

        base_url = f'https://api.tequila.kiwi.com/v2/search?fly_from=BUD&curr=HUF' \
                   f'&fly_to={airport}' \
                   f'&date_from={date_from}' \
                   f'&date_to={date_to}' \
                   f'&nights_in_dst_from={nights_in_dst_from}' \
                   f'&nights_in_dst_to={nights_in_dst_to}' \
                   f'&flight_type=round' \
                   f'&adults={adults}' \
                   f'&children={children}' \
                   f'&infants={infants}' \
                   f'&adult_hold_bag={adult_hold_bag}' \
                   f'&adult_hand_bag={adult_hand_bag}' \
                   f'&max_stopovers={max_stopovers}' \


        #log.info(base_url)

        r = requests.get(url=base_url, headers={"apikey": api_key})
        data = r.json()

        flight_result = FlightResultModel.from_dict(data)
        
        if (flight_result != None) & (len(flight_result.data)) > 0:
            
            result_list = []
    
            for data in flight_result.data:

                result_dict = {}

                result_dict['ID'] = data.id
                result_dict['PRICE'] = data.price
                result_dict['FLY_DURATION'] = np.round(int(data.duration.departure) / 3600, 2)
                result_dict['RET_DURATION'] = np.round(int(data.duration.duration_return) / 3600, 2) 
                result_dict['TOTAL_DURATION'] = np.round(int(data.duration.total) / 3600, 2)

                return_type = 0
                col_suffix = 'OUT'

                for route in data.route:

                    if return_type == 1:
                        col_suffix = 'BACK'

                    result_dict['ID_' + str(col_suffix)] = route.id
                    result_dict['DEP_DATE_' + str(col_suffix)] = route.local_departure
                    result_dict['ARR_DATE_' + str(col_suffix)] = route.local_arrival

                    result_dict['AIRLINE_' + str(col_suffix)] = route.airline
                    result_dict['CITY_FROM_' + str(col_suffix)] = route.city_from
                    result_dict['CITY_TO_' + str(col_suffix)] = route.city_to
                    result_dict['FLIGHT_NO_' + str(col_suffix)] = route.flight_no

                    return_type = return_type + 1


                result_list.append(result_dict)
                #log.debug(result_dict)
                
            df = pd.DataFrame(result_list)
            df['PRICE'] = df['PRICE'].astype(int)

            log.debug(f'Result dataframe len: {len(df)}')
            flight_result_list.append(df)
            
        else:
            
            log.debug('no routes found!')
            
    final_result = reduce(lambda left, right: pd.concat([left, right]), flight_result_list)
    final_result.sort_values('PRICE', inplace=True)
    final_result.reset_index(inplace=True, drop=True)
    final_result['DEP_DATE_OUT'] = final_result['DEP_DATE_OUT'].dt.strftime('%Y-%m-%d %H:%M')
    final_result['ARR_DATE_OUT'] = final_result['ARR_DATE_OUT'].dt.strftime('%Y-%m-%d %H:%M')
    final_result['DEP_DATE_BACK'] = final_result['DEP_DATE_BACK'].dt.strftime('%Y-%m-%d %H:%M')
    final_result['ARR_DATE_BACK'] = final_result['ARR_DATE_BACK'].dt.strftime('%Y-%m-%d %H:%M')
    
    return final_result

# %%
final_result = get_data_from_api()
# Out:
# 2023-03-11 14:13:31 - INFO - get_data_from_api started!
# 2023-03-11 14:13:31 - DEBUG - Checking BUD to TIA
# 2023-03-11 14:13:33 - DEBUG - Result dataframe len: 59
# 2023-03-11 14:13:33 - DEBUG - Checking BUD to EVN
# 2023-03-11 14:13:33 - DEBUG - no routes found!
# 2023-03-11 14:13:33 - DEBUG - Checking BUD to GRZ
# 2023-03-11 14:13:35 - DEBUG - no routes found!
# 2023-03-11 14:13:35 - DEBUG - Checking BUD to INN
# 2023-03-11 14:13:36 - DEBUG - no routes found!
# 2023-03-11 14:13:36 - DEBUG - Checking BUD to KLU
# 2023-03-11 14:13:36 - DEBUG - no routes found!
# 2023-03-11 14:13:36 - DEBUG - Checking BUD to LNZ
# 2023-03-11 14:13:37 - DEBUG - no routes found!
# 2023-03-11 14:13:37 - DEBUG - Checking BUD to SZG
# 2023-03-11 14:13:39 - DEBUG - no routes found!
# 2023-03-11 14:13:39 - DEBUG - Checking BUD to VIE
# 2023-03-11 14:13:41 - DEBUG - no routes found!
# 2023-03-11 14:13:41 - DEBUG - Checking BUD to GYD
# 2023-03-11 14:13:43 - DEBUG - no routes found!
# 2023-03-11 14:13:43 - DEBUG - Checking BUD to MSQ
# 2023-03-11 14:13:44 - DEBUG - no routes found!
# 2023-03-11 14:13:44 - DEBUG - Checking BUD to ANR
# 2023-03-11 14:13:45 - DEBUG - no routes found!
# 2023-03-11 14:13:45 - DEBUG - Checking BUD to BRU
# 2023-03-11 14:13:49 - DEBUG - no routes found!
# 2023-03-11 14:13:49 - DEBUG - Checking BUD to CRL
# 2023-03-11 14:13:54 - DEBUG - no routes found!
# 2023-03-11 14:13:54 - DEBUG - Checking BUD to LGG
# 2023-03-11 14:13:54 - DEBUG - no routes found!
# 2023-03-11 14:13:54 - DEBUG - Checking BUD to OST
# 2023-03-11 14:13:55 - DEBUG - no routes found!
# 2023-03-11 14:13:55 - DEBUG - Checking BUD to SJJ
# 2023-03-11 14:13:56 - DEBUG - no routes found!
# 2023-03-11 14:13:56 - DEBUG - Checking BUD to TZL
# 2023-03-11 14:13:57 - DEBUG - no routes found!
# 2023-03-11 14:13:57 - DEBUG - Checking BUD to BOJ
# 2023-03-11 14:13:58 - DEBUG - Result dataframe len: 153
# 2023-03-11 14:13:58 - DEBUG - Checking BUD to SOF
# 2023-03-11 14:14:02 - DEBUG - no routes found!
# 2023-03-11 14:14:02 - DEBUG - Checking BUD to VAR
# 2023-03-11 14:14:02 - DEBUG - no routes found!
# 2023-03-11 14:14:02 - DEBUG - Checking BUD to DBV
# 2023-03-11 14:14:03 - DEBUG - no routes found!
# 2023-03-11 14:14:03 - DEBUG - Checking BUD to PUY
# 2023-03-11 14:14:04 - DEBUG - no routes found!
# 2023-03-11 14:14:04 - DEBUG - Checking BUD to SPU
# 2023-03-11 14:14:05 - DEBUG - no routes found!
# 2023-03-11 14:14:05 - DEBUG - Checking BUD to ZAD
# 2023-03-11 14:14:05 - DEBUG - no routes found!
# 2023-03-11 14:14:05 - DEBUG - Checking BUD to ZAG
# 2023-03-11 14:14:06 - DEBUG - no routes found!
# 2023-03-11 14:14:06 - DEBUG - Checking BUD to LCA
# 2023-03-11 14:14:09 - DEBUG - no routes found!
# 2023-03-11 14:14:09 - DEBUG - Checking BUD to PFO
# 2023-03-11 14:14:10 - DEBUG - no routes found!
# 2023-03-11 14:14:10 - DEBUG - Checking BUD to BRQ
# 2023-03-11 14:14:11 - DEBUG - no routes found!
# 2023-03-11 14:14:11 - DEBUG - Checking BUD to PRG
# 2023-03-11 14:14:17 - DEBUG - no routes found!
# 2023-03-11 14:14:17 - DEBUG - Checking BUD to AAL
# 2023-03-11 14:14:18 - DEBUG - no routes found!
# 2023-03-11 14:14:18 - DEBUG - Checking BUD to AAR
# 2023-03-11 14:14:20 - DEBUG - no routes found!
# 2023-03-11 14:14:20 - DEBUG - Checking BUD to BLL
# 2023-03-11 14:14:22 - DEBUG - no routes found!
# 2023-03-11 14:14:22 - DEBUG - Checking BUD to CPH
# 2023-03-11 14:14:24 - DEBUG - Result dataframe len: 283
# 2023-03-11 14:14:24 - DEBUG - Checking BUD to FAE
# 2023-03-11 14:14:26 - DEBUG - no routes found!
# 2023-03-11 14:14:26 - DEBUG - Checking BUD to TLL
# 2023-03-11 14:14:26 - DEBUG - no routes found!
# 2023-03-11 14:14:26 - DEBUG - Checking BUD to HEL
# 2023-03-11 14:14:29 - DEBUG - no routes found!
# 2023-03-11 14:14:29 - DEBUG - Checking BUD to OUL
# 2023-03-11 14:14:30 - DEBUG - no routes found!
# 2023-03-11 14:14:30 - DEBUG - Checking BUD to RVN
# 2023-03-11 14:14:32 - DEBUG - no routes found!
# 2023-03-11 14:14:32 - DEBUG - Checking BUD to TMP
# 2023-03-11 14:14:32 - DEBUG - no routes found!
# 2023-03-11 14:14:32 - DEBUG - Checking BUD to TKU
# 2023-03-11 14:14:33 - DEBUG - no routes found!
# 2023-03-11 14:14:33 - DEBUG - Checking BUD to VAA
# 2023-03-11 14:14:34 - DEBUG - no routes found!
# 2023-03-11 14:14:34 - DEBUG - Checking BUD to AJA
# 2023-03-11 14:14:35 - DEBUG - no routes found!
# 2023-03-11 14:14:35 - DEBUG - Checking BUD to BIA
# 2023-03-11 14:14:35 - DEBUG - no routes found!
# 2023-03-11 14:14:35 - DEBUG - Checking BUD to EGC
# 2023-03-11 14:14:36 - DEBUG - no routes found!
# 2023-03-11 14:14:36 - DEBUG - Checking BUD to BIQ
# 2023-03-11 14:14:36 - DEBUG - no routes found!
# 2023-03-11 14:14:36 - DEBUG - Checking BUD to BOD
# 2023-03-11 14:14:37 - DEBUG - no routes found!
# 2023-03-11 14:14:37 - DEBUG - Checking BUD to BES
# 2023-03-11 14:14:37 - DEBUG - no routes found!
# 2023-03-11 14:14:37 - DEBUG - Checking BUD to FSC
# 2023-03-11 14:14:38 - DEBUG - no routes found!
# 2023-03-11 14:14:38 - DEBUG - Checking BUD to LIL
# 2023-03-11 14:14:39 - DEBUG - no routes found!
# 2023-03-11 14:14:39 - DEBUG - Checking BUD to LYS
# 2023-03-11 14:14:40 - DEBUG - no routes found!
# 2023-03-11 14:14:40 - DEBUG - Checking BUD to MRS
# 2023-03-11 14:14:42 - DEBUG - Result dataframe len: 55
# 2023-03-11 14:14:42 - DEBUG - Checking BUD to MPL
# 2023-03-11 14:14:42 - DEBUG - no routes found!
# 2023-03-11 14:14:42 - DEBUG - Checking BUD to NTE
# 2023-03-11 14:14:43 - DEBUG - no routes found!
# 2023-03-11 14:14:43 - DEBUG - Checking BUD to NCE
# 2023-03-11 14:14:46 - DEBUG - no routes found!
# 2023-03-11 14:14:46 - DEBUG - Checking BUD to BVA
# 2023-03-11 14:14:48 - DEBUG - Result dataframe len: 181
# 2023-03-11 14:14:48 - DEBUG - Checking BUD to CDG
# 2023-03-11 14:14:50 - DEBUG - no routes found!
# 2023-03-11 14:14:50 - DEBUG - Checking BUD to ORY
# 2023-03-11 14:14:52 - DEBUG - no routes found!
# 2023-03-11 14:14:52 - DEBUG - Checking BUD to SXB
# 2023-03-11 14:14:52 - DEBUG - no routes found!
# 2023-03-11 14:14:52 - DEBUG - Checking BUD to RNS
# 2023-03-11 14:14:53 - DEBUG - no routes found!
# 2023-03-11 14:14:53 - DEBUG - Checking BUD to RUN
# 2023-03-11 14:14:53 - DEBUG - no routes found!
# 2023-03-11 14:14:53 - DEBUG - Checking BUD to TLN
# 2023-03-11 14:14:54 - DEBUG - no routes found!
# 2023-03-11 14:14:54 - DEBUG - Checking BUD to TLS
# 2023-03-11 14:14:55 - DEBUG - no routes found!
# 2023-03-11 14:14:55 - DEBUG - Checking BUD to KUT
# 2023-03-11 14:15:02 - DEBUG - no routes found!
# 2023-03-11 14:15:02 - DEBUG - Checking BUD to TBS
# 2023-03-11 14:15:02 - DEBUG - no routes found!
# 2023-03-11 14:15:02 - DEBUG - Checking BUD to FMM
# 2023-03-11 14:15:02 - DEBUG - no routes found!
# 2023-03-11 14:15:02 - DEBUG - Checking BUD to BER
# 2023-03-11 14:15:06 - DEBUG - no routes found!
# 2023-03-11 14:15:06 - DEBUG - Checking BUD to SXF
# 2023-03-11 14:15:08 - DEBUG - no routes found!
# 2023-03-11 14:15:08 - DEBUG - Checking BUD to TXL
# 2023-03-11 14:15:09 - DEBUG - no routes found!
# 2023-03-11 14:15:09 - DEBUG - Checking BUD to BRE
# 2023-03-11 14:15:10 - DEBUG - no routes found!
# 2023-03-11 14:15:10 - DEBUG - Checking BUD to CGN
# 2023-03-11 14:15:11 - DEBUG - Result dataframe len: 169
# 2023-03-11 14:15:11 - DEBUG - Checking BUD to DTM
# 2023-03-11 14:15:13 - DEBUG - no routes found!
# 2023-03-11 14:15:13 - DEBUG - Checking BUD to DRS
# 2023-03-11 14:15:14 - DEBUG - no routes found!
# 2023-03-11 14:15:14 - DEBUG - Checking BUD to DUS
# 2023-03-11 14:15:17 - DEBUG - no routes found!
# 2023-03-11 14:15:17 - DEBUG - Checking BUD to FRA
# 2023-03-11 14:15:19 - DEBUG - no routes found!
# 2023-03-11 14:15:19 - DEBUG - Checking BUD to HHN
# 2023-03-11 14:15:19 - DEBUG - no routes found!
# 2023-03-11 14:15:19 - DEBUG - Checking BUD to FDH
# 2023-03-11 14:15:20 - DEBUG - no routes found!
# 2023-03-11 14:15:20 - DEBUG - Checking BUD to HAM
# 2023-03-11 14:15:22 - DEBUG - no routes found!
# 2023-03-11 14:15:22 - DEBUG - Checking BUD to HAJ
# 2023-03-11 14:15:23 - DEBUG - no routes found!
# 2023-03-11 14:15:23 - DEBUG - Checking BUD to FKB
# 2023-03-11 14:15:23 - DEBUG - no routes found!
# 2023-03-11 14:15:23 - DEBUG - Checking BUD to LEJ
# 2023-03-11 14:15:24 - DEBUG - no routes found!
# 2023-03-11 14:15:24 - DEBUG - Checking BUD to MUC
# 2023-03-11 14:15:26 - DEBUG - Result dataframe len: 243
# 2023-03-11 14:15:26 - DEBUG - Checking BUD to FMO
# 2023-03-11 14:15:27 - DEBUG - no routes found!
# 2023-03-11 14:15:27 - DEBUG - Checking BUD to NUE
# 2023-03-11 14:15:28 - DEBUG - Result dataframe len: 59
# 2023-03-11 14:15:28 - DEBUG - Checking BUD to PAD
# 2023-03-11 14:15:30 - DEBUG - no routes found!
# 2023-03-11 14:15:30 - DEBUG - Checking BUD to STR
# 2023-03-11 14:15:36 - DEBUG - no routes found!
# 2023-03-11 14:15:36 - DEBUG - Checking BUD to NRN
# 2023-03-11 14:15:36 - DEBUG - no routes found!
# 2023-03-11 14:15:36 - DEBUG - Checking BUD to ATH
# 2023-03-11 14:15:40 - DEBUG - no routes found!
# 2023-03-11 14:15:40 - DEBUG - Checking BUD to CHQ
# 2023-03-11 14:15:41 - DEBUG - Result dataframe len: 93
# 2023-03-11 14:15:41 - DEBUG - Checking BUD to CFU
# 2023-03-11 14:15:45 - DEBUG - no routes found!
# 2023-03-11 14:15:45 - DEBUG - Checking BUD to HER
# 2023-03-11 14:15:46 - DEBUG - no routes found!
# 2023-03-11 14:15:46 - DEBUG - Checking BUD to KGS
# 2023-03-11 14:15:47 - DEBUG - no routes found!
# 2023-03-11 14:15:47 - DEBUG - Checking BUD to JMK
# 2023-03-11 14:15:48 - DEBUG - no routes found!
# 2023-03-11 14:15:48 - DEBUG - Checking BUD to RHO
# 2023-03-11 14:15:50 - DEBUG - Result dataframe len: 93
# 2023-03-11 14:15:50 - DEBUG - Checking BUD to JTR
# 2023-03-11 14:15:50 - DEBUG - Result dataframe len: 29
# 2023-03-11 14:15:50 - DEBUG - Checking BUD to SKG
# 2023-03-11 14:15:53 - DEBUG - Result dataframe len: 165
# 2023-03-11 14:15:53 - DEBUG - Checking BUD to ZTH
# 2023-03-11 14:15:54 - DEBUG - Result dataframe len: 59
# 2023-03-11 14:15:54 - DEBUG - Checking BUD to BUD
# 2023-03-11 14:15:56 - DEBUG - no routes found!
# 2023-03-11 14:15:56 - DEBUG - Checking BUD to DEB
# 2023-03-11 14:15:58 - DEBUG - no routes found!
# 2023-03-11 14:15:58 - DEBUG - Checking BUD to KEF
# 2023-03-11 14:15:59 - DEBUG - no routes found!
# 2023-03-11 14:15:59 - DEBUG - Checking BUD to ORK
# 2023-03-11 14:16:00 - DEBUG - no routes found!
# 2023-03-11 14:16:00 - DEBUG - Checking BUD to DUB
# 2023-03-11 14:16:02 - DEBUG - no routes found!
# 2023-03-11 14:16:02 - DEBUG - Checking BUD to NOC
# 2023-03-11 14:16:04 - DEBUG - no routes found!
# 2023-03-11 14:16:04 - DEBUG - Checking BUD to KIR
# 2023-03-11 14:16:05 - DEBUG - no routes found!
# 2023-03-11 14:16:05 - DEBUG - Checking BUD to SNN
# 2023-03-11 14:16:05 - DEBUG - Result dataframe len: 3
# 2023-03-11 14:16:05 - DEBUG - Checking BUD to AHO
# 2023-03-11 14:16:07 - DEBUG - Result dataframe len: 123
# 2023-03-11 14:16:07 - DEBUG - Checking BUD to AOI
# 2023-03-11 14:16:07 - DEBUG - no routes found!
# 2023-03-11 14:16:07 - DEBUG - Checking BUD to BRI
# 2023-03-11 14:16:10 - DEBUG - no routes found!
# 2023-03-11 14:16:10 - DEBUG - Checking BUD to BGY
# 2023-03-11 14:16:12 - DEBUG - no routes found!
# 2023-03-11 14:16:12 - DEBUG - Checking BUD to BLQ
# 2023-03-11 14:16:14 - DEBUG - Result dataframe len: 57
# 2023-03-11 14:16:14 - DEBUG - Checking BUD to BDS
# 2023-03-11 14:16:15 - DEBUG - no routes found!
# 2023-03-11 14:16:15 - DEBUG - Checking BUD to CAG
# 2023-03-11 14:16:17 - DEBUG - Result dataframe len: 57
# 2023-03-11 14:16:17 - DEBUG - Checking BUD to CTA
# 2023-03-11 14:16:19 - DEBUG - Result dataframe len: 249
# 2023-03-11 14:16:19 - DEBUG - Checking BUD to CIY
# 2023-03-11 14:16:20 - DEBUG - no routes found!
# 2023-03-11 14:16:20 - DEBUG - Checking BUD to FLR
# 2023-03-11 14:16:21 - DEBUG - no routes found!
# 2023-03-11 14:16:21 - DEBUG - Checking BUD to GOA
# 2023-03-11 14:16:23 - DEBUG - no routes found!
# 2023-03-11 14:16:23 - DEBUG - Checking BUD to SUF
# 2023-03-11 14:16:24 - DEBUG - no routes found!
# 2023-03-11 14:16:24 - DEBUG - Checking BUD to LIN
# 2023-03-11 14:16:26 - DEBUG - no routes found!
# 2023-03-11 14:16:26 - DEBUG - Checking BUD to MXP
# 2023-03-11 14:16:30 - DEBUG - no routes found!
# 2023-03-11 14:16:30 - DEBUG - Checking BUD to NAP
# 2023-03-11 14:16:33 - DEBUG - no routes found!
# 2023-03-11 14:16:33 - DEBUG - Checking BUD to OLB
# 2023-03-11 14:16:34 - DEBUG - no routes found!
# 2023-03-11 14:16:34 - DEBUG - Checking BUD to PMO
# 2023-03-11 14:16:36 - DEBUG - no routes found!
# 2023-03-11 14:16:36 - DEBUG - Checking BUD to PEG
# 2023-03-11 14:16:36 - DEBUG - no routes found!
# 2023-03-11 14:16:36 - DEBUG - Checking BUD to PSR
# 2023-03-11 14:16:37 - DEBUG - no routes found!
# 2023-03-11 14:16:37 - DEBUG - Checking BUD to PSA
# 2023-03-11 14:16:38 - DEBUG - Result dataframe len: 77
# 2023-03-11 14:16:38 - DEBUG - Checking BUD to CIA
# 2023-03-11 14:16:42 - DEBUG - no routes found!
# 2023-03-11 14:16:42 - DEBUG - Checking BUD to FCO
# 2023-03-11 14:16:44 - DEBUG - no routes found!
# 2023-03-11 14:16:44 - DEBUG - Checking BUD to TPS
# 2023-03-11 14:16:46 - DEBUG - no routes found!
# 2023-03-11 14:16:46 - DEBUG - Checking BUD to TSF
# 2023-03-11 14:16:47 - DEBUG - no routes found!
# 2023-03-11 14:16:47 - DEBUG - Checking BUD to TRN
# 2023-03-11 14:16:48 - DEBUG - no routes found!
# 2023-03-11 14:16:48 - DEBUG - Checking BUD to VCE
# 2023-03-11 14:16:50 - DEBUG - no routes found!
# 2023-03-11 14:16:50 - DEBUG - Checking BUD to VRN
# 2023-03-11 14:16:51 - DEBUG - no routes found!
# 2023-03-11 14:16:51 - DEBUG - Checking BUD to ALA
# 2023-03-11 14:16:53 - DEBUG - no routes found!
# 2023-03-11 14:16:53 - DEBUG - Checking BUD to TSE
# 2023-03-11 14:16:54 - DEBUG - no routes found!
# 2023-03-11 14:16:54 - DEBUG - Checking BUD to PRN
# 2023-03-11 14:16:54 - DEBUG - no routes found!
# 2023-03-11 14:16:54 - DEBUG - Checking BUD to RIX
# 2023-03-11 14:16:56 - DEBUG - Result dataframe len: 53
# 2023-03-11 14:16:56 - DEBUG - Checking BUD to KUN
# 2023-03-11 14:16:57 - DEBUG - no routes found!
# 2023-03-11 14:16:57 - DEBUG - Checking BUD to VNO
# 2023-03-11 14:16:58 - DEBUG - no routes found!
# 2023-03-11 14:16:58 - DEBUG - Checking BUD to LUX
# 2023-03-11 14:17:06 - DEBUG - Result dataframe len: 105
# 2023-03-11 14:17:06 - DEBUG - Checking BUD to MLA
# 2023-03-11 14:17:09 - DEBUG - no routes found!
# 2023-03-11 14:17:09 - DEBUG - Checking BUD to KIV
# 2023-03-11 14:17:10 - DEBUG - no routes found!
# 2023-03-11 14:17:10 - DEBUG - Checking BUD to TGD
# 2023-03-11 14:17:11 - DEBUG - Result dataframe len: 57
# 2023-03-11 14:17:11 - DEBUG - Checking BUD to TIV
# 2023-03-11 14:17:12 - DEBUG - no routes found!
# 2023-03-11 14:17:12 - DEBUG - Checking BUD to AMS
# 2023-03-11 14:17:15 - DEBUG - Result dataframe len: 287
# 2023-03-11 14:17:15 - DEBUG - Checking BUD to EIN
# 2023-03-11 14:17:19 - DEBUG - no routes found!
# 2023-03-11 14:17:19 - DEBUG - Checking BUD to GRQ
# 2023-03-11 14:17:19 - DEBUG - no routes found!
# 2023-03-11 14:17:19 - DEBUG - Checking BUD to MST
# 2023-03-11 14:17:20 - DEBUG - no routes found!
# 2023-03-11 14:17:20 - DEBUG - Checking BUD to RTM
# 2023-03-11 14:17:22 - DEBUG - no routes found!
# 2023-03-11 14:17:22 - DEBUG - Checking BUD to SKP
# 2023-03-11 14:17:23 - DEBUG - no routes found!
# 2023-03-11 14:17:23 - DEBUG - Checking BUD to AES
# 2023-03-11 14:17:24 - DEBUG - no routes found!
# 2023-03-11 14:17:24 - DEBUG - Checking BUD to BGO
# 2023-03-11 14:17:25 - DEBUG - no routes found!
# 2023-03-11 14:17:25 - DEBUG - Checking BUD to BOO
# 2023-03-11 14:17:26 - DEBUG - no routes found!
# 2023-03-11 14:17:26 - DEBUG - Checking BUD to HAU
# 2023-03-11 14:17:27 - DEBUG - no routes found!
# 2023-03-11 14:17:27 - DEBUG - Checking BUD to KRS
# 2023-03-11 14:17:27 - DEBUG - no routes found!
# 2023-03-11 14:17:27 - DEBUG - Checking BUD to OSL
# 2023-03-11 14:17:31 - DEBUG - Result dataframe len: 207
# 2023-03-11 14:17:31 - DEBUG - Checking BUD to TRF
# 2023-03-11 14:17:33 - DEBUG - no routes found!
# 2023-03-11 14:17:33 - DEBUG - Checking BUD to SVG
# 2023-03-11 14:17:34 - DEBUG - no routes found!
# 2023-03-11 14:17:34 - DEBUG - Checking BUD to TOS
# 2023-03-11 14:17:35 - DEBUG - no routes found!
# 2023-03-11 14:17:35 - DEBUG - Checking BUD to TRD
# 2023-03-11 14:17:37 - DEBUG - no routes found!
# 2023-03-11 14:17:37 - DEBUG - Checking BUD to GDN
# 2023-03-11 14:17:38 - DEBUG - no routes found!
# 2023-03-11 14:17:38 - DEBUG - Checking BUD to KTW
# 2023-03-11 14:17:38 - DEBUG - no routes found!
# 2023-03-11 14:17:38 - DEBUG - Checking BUD to KRK
# 2023-03-11 14:17:39 - DEBUG - no routes found!
# 2023-03-11 14:17:39 - DEBUG - Checking BUD to POZ
# 2023-03-11 14:17:41 - DEBUG - Result dataframe len: 113
# 2023-03-11 14:17:41 - DEBUG - Checking BUD to SZZ
# 2023-03-11 14:17:42 - DEBUG - no routes found!
# 2023-03-11 14:17:42 - DEBUG - Checking BUD to WAW
# 2023-03-11 14:17:44 - DEBUG - Result dataframe len: 249
# 2023-03-11 14:17:44 - DEBUG - Checking BUD to WMI
# 2023-03-11 14:17:46 - DEBUG - no routes found!
# 2023-03-11 14:17:46 - DEBUG - Checking BUD to WRO
# 2023-03-11 14:17:47 - DEBUG - no routes found!
# 2023-03-11 14:17:47 - DEBUG - Checking BUD to FAO
# 2023-03-11 14:17:47 - DEBUG - no routes found!
# 2023-03-11 14:17:47 - DEBUG - Checking BUD to LIS
# 2023-03-11 14:17:49 - DEBUG - no routes found!
# 2023-03-11 14:17:49 - DEBUG - Checking BUD to FNC
# 2023-03-11 14:17:51 - DEBUG - Result dataframe len: 59
# 2023-03-11 14:17:51 - DEBUG - Checking BUD to PDL
# 2023-03-11 14:17:52 - DEBUG - no routes found!
# 2023-03-11 14:17:52 - DEBUG - Checking BUD to OPO
# 2023-03-11 14:17:53 - DEBUG - Result dataframe len: 67
# 2023-03-11 14:17:53 - DEBUG - Checking BUD to OTP
# 2023-03-11 14:17:56 - DEBUG - Result dataframe len: 295
# 2023-03-11 14:17:56 - DEBUG - Checking BUD to CLJ
# 2023-03-11 14:17:57 - DEBUG - Result dataframe len: 55
# 2023-03-11 14:17:57 - DEBUG - Checking BUD to IAS
# 2023-03-11 14:17:59 - DEBUG - no routes found!
# 2023-03-11 14:17:59 - DEBUG - Checking BUD to TSR
# 2023-03-11 14:18:00 - DEBUG - no routes found!
# 2023-03-11 14:18:00 - DEBUG - Checking BUD to SVX
# 2023-03-11 14:18:01 - DEBUG - no routes found!
# 2023-03-11 14:18:01 - DEBUG - Checking BUD to KRR
# 2023-03-11 14:18:02 - DEBUG - no routes found!
# 2023-03-11 14:18:02 - DEBUG - Checking BUD to DME
# 2023-03-11 14:18:02 - DEBUG - no routes found!
# 2023-03-11 14:18:02 - DEBUG - Checking BUD to SVO
# 2023-03-11 14:18:04 - DEBUG - no routes found!
# 2023-03-11 14:18:04 - DEBUG - Checking BUD to VKO
# 2023-03-11 14:18:05 - DEBUG - no routes found!
# 2023-03-11 14:18:05 - DEBUG - Checking BUD to ZIA
# 2023-03-11 14:18:06 - DEBUG - no routes found!
# 2023-03-11 14:18:06 - DEBUG - Checking BUD to OVB
# 2023-03-11 14:18:07 - DEBUG - no routes found!
# 2023-03-11 14:18:07 - DEBUG - Checking BUD to LED
# 2023-03-11 14:18:08 - DEBUG - no routes found!
# 2023-03-11 14:18:08 - DEBUG - Checking BUD to AER
# 2023-03-11 14:18:08 - DEBUG - no routes found!
# 2023-03-11 14:18:08 - DEBUG - Checking BUD to BEG
# 2023-03-11 14:18:10 - DEBUG - Result dataframe len: 239
# 2023-03-11 14:18:10 - DEBUG - Checking BUD to INI
# 2023-03-11 14:18:10 - DEBUG - no routes found!
# 2023-03-11 14:18:10 - DEBUG - Checking BUD to BTS
# 2023-03-11 14:18:11 - DEBUG - no routes found!
# 2023-03-11 14:18:11 - DEBUG - Checking BUD to KSC
# 2023-03-11 14:18:13 - DEBUG - no routes found!
# 2023-03-11 14:18:13 - DEBUG - Checking BUD to LJU
# 2023-03-11 14:18:14 - DEBUG - no routes found!
# 2023-03-11 14:18:14 - DEBUG - Checking BUD to ALC
# 2023-03-11 14:18:16 - DEBUG - no routes found!
# 2023-03-11 14:18:16 - DEBUG - Checking BUD to LEI
# 2023-03-11 14:18:17 - DEBUG - no routes found!
# 2023-03-11 14:18:17 - DEBUG - Checking BUD to OVD
# 2023-03-11 14:18:18 - DEBUG - no routes found!
# 2023-03-11 14:18:18 - DEBUG - Checking BUD to BCN
# 2023-03-11 14:18:21 - DEBUG - no routes found!
# 2023-03-11 14:18:21 - DEBUG - Checking BUD to BIO
# 2023-03-11 14:18:22 - DEBUG - no routes found!
# 2023-03-11 14:18:22 - DEBUG - Checking BUD to FUE
# 2023-03-11 14:18:25 - DEBUG - no routes found!
# 2023-03-11 14:18:25 - DEBUG - Checking BUD to GRO
# 2023-03-11 14:18:26 - DEBUG - no routes found!
# 2023-03-11 14:18:26 - DEBUG - Checking BUD to LPA
# 2023-03-11 14:18:27 - DEBUG - no routes found!
# 2023-03-11 14:18:27 - DEBUG - Checking BUD to GRX
# 2023-03-11 14:18:27 - DEBUG - no routes found!
# 2023-03-11 14:18:27 - DEBUG - Checking BUD to IBZ
# 2023-03-11 14:18:28 - DEBUG - no routes found!
# 2023-03-11 14:18:28 - DEBUG - Checking BUD to XRY
# 2023-03-11 14:18:29 - DEBUG - no routes found!
# 2023-03-11 14:18:29 - DEBUG - Checking BUD to SPC
# 2023-03-11 14:18:30 - DEBUG - no routes found!
# 2023-03-11 14:18:30 - DEBUG - Checking BUD to ACE
# 2023-03-11 14:18:31 - DEBUG - no routes found!
# 2023-03-11 14:18:31 - DEBUG - Checking BUD to MAD
# 2023-03-11 14:18:34 - DEBUG - no routes found!
# 2023-03-11 14:18:34 - DEBUG - Checking BUD to AGP
# 2023-03-11 14:18:36 - DEBUG - no routes found!
# 2023-03-11 14:18:36 - DEBUG - Checking BUD to MAH
# 2023-03-11 14:18:38 - DEBUG - no routes found!
# 2023-03-11 14:18:38 - DEBUG - Checking BUD to PMI
# 2023-03-11 14:18:40 - DEBUG - no routes found!
# 2023-03-11 14:18:40 - DEBUG - Checking BUD to RMU
# 2023-03-11 14:18:40 - DEBUG - no routes found!
# 2023-03-11 14:18:40 - DEBUG - Checking BUD to REU
# 2023-03-11 14:18:41 - DEBUG - no routes found!
# 2023-03-11 14:18:41 - DEBUG - Checking BUD to SDR
# 2023-03-11 14:18:42 - DEBUG - no routes found!
# 2023-03-11 14:18:42 - DEBUG - Checking BUD to SCQ
# 2023-03-11 14:18:44 - DEBUG - no routes found!
# 2023-03-11 14:18:44 - DEBUG - Checking BUD to SVQ
# 2023-03-11 14:18:45 - DEBUG - Result dataframe len: 3
# 2023-03-11 14:18:45 - DEBUG - Checking BUD to TFN
# 2023-03-11 14:18:46 - DEBUG - no routes found!
# 2023-03-11 14:18:46 - DEBUG - Checking BUD to TFS
# 2023-03-11 14:18:47 - DEBUG - no routes found!
# 2023-03-11 14:18:47 - DEBUG - Checking BUD to VLC
# 2023-03-11 14:18:48 - DEBUG - Result dataframe len: 55
# 2023-03-11 14:18:48 - DEBUG - Checking BUD to ZAZ
# 2023-03-11 14:18:50 - DEBUG - no routes found!
# 2023-03-11 14:18:50 - DEBUG - Checking BUD to GOT
# 2023-03-11 14:18:51 - DEBUG - no routes found!
# 2023-03-11 14:18:51 - DEBUG - Checking BUD to MMX
# 2023-03-11 14:18:52 - DEBUG - no routes found!
# 2023-03-11 14:18:52 - DEBUG - Checking BUD to ARN
# 2023-03-11 14:18:54 - DEBUG - no routes found!
# 2023-03-11 14:18:54 - DEBUG - Checking BUD to BMA
# 2023-03-11 14:18:55 - DEBUG - no routes found!
# 2023-03-11 14:18:55 - DEBUG - Checking BUD to NYO
# 2023-03-11 14:19:00 - DEBUG - no routes found!
# 2023-03-11 14:19:00 - DEBUG - Checking BUD to VST
# 2023-03-11 14:19:01 - DEBUG - no routes found!
# 2023-03-11 14:19:01 - DEBUG - Checking BUD to BSL
# 2023-03-11 14:19:05 - DEBUG - no routes found!
# 2023-03-11 14:19:05 - DEBUG - Checking BUD to BRN
# 2023-03-11 14:19:07 - DEBUG - no routes found!
# 2023-03-11 14:19:07 - DEBUG - Checking BUD to GVA
# 2023-03-11 14:19:08 - DEBUG - no routes found!
# 2023-03-11 14:19:08 - DEBUG - Checking BUD to ZRH
# 2023-03-11 14:19:11 - DEBUG - Result dataframe len: 249
# 2023-03-11 14:19:11 - DEBUG - Checking BUD to ADA
# 2023-03-11 14:19:11 - DEBUG - no routes found!
# 2023-03-11 14:19:11 - DEBUG - Checking BUD to ESB
# 2023-03-11 14:19:12 - DEBUG - no routes found!
# 2023-03-11 14:19:12 - DEBUG - Checking BUD to AYT
# 2023-03-11 14:19:14 - DEBUG - no routes found!
# 2023-03-11 14:19:14 - DEBUG - Checking BUD to DLM
# 2023-03-11 14:19:15 - DEBUG - no routes found!
# 2023-03-11 14:19:15 - DEBUG - Checking BUD to IST
# 2023-03-11 14:19:21 - DEBUG - Result dataframe len: 299
# 2023-03-11 14:19:21 - DEBUG - Checking BUD to SAW
# 2023-03-11 14:19:26 - DEBUG - Result dataframe len: 267
# 2023-03-11 14:19:26 - DEBUG - Checking BUD to ADB
# 2023-03-11 14:19:27 - DEBUG - no routes found!
# 2023-03-11 14:19:27 - DEBUG - Checking BUD to BJV
# 2023-03-11 14:19:27 - DEBUG - no routes found!
# 2023-03-11 14:19:27 - DEBUG - Checking BUD to TZX
# 2023-03-11 14:19:28 - DEBUG - no routes found!
# 2023-03-11 14:19:28 - DEBUG - Checking BUD to HRK
# 2023-03-11 14:19:29 - DEBUG - no routes found!
# 2023-03-11 14:19:29 - DEBUG - Checking BUD to KBP
# 2023-03-11 14:19:30 - DEBUG - no routes found!
# 2023-03-11 14:19:30 - DEBUG - Checking BUD to IEV
# 2023-03-11 14:19:30 - DEBUG - no routes found!
# 2023-03-11 14:19:30 - DEBUG - Checking BUD to LWO
# 2023-03-11 14:19:32 - DEBUG - no routes found!
# 2023-03-11 14:19:32 - DEBUG - Checking BUD to ODS
# 2023-03-11 14:19:33 - DEBUG - no routes found!
# 2023-03-11 14:19:33 - DEBUG - Checking BUD to ABZ
# 2023-03-11 14:19:35 - DEBUG - no routes found!
# 2023-03-11 14:19:35 - DEBUG - Checking BUD to BHD
# 2023-03-11 14:19:36 - DEBUG - no routes found!
# 2023-03-11 14:19:36 - DEBUG - Checking BUD to BFS
# 2023-03-11 14:19:37 - DEBUG - no routes found!
# 2023-03-11 14:19:37 - DEBUG - Checking BUD to BHX
# 2023-03-11 14:19:39 - DEBUG - no routes found!
# 2023-03-11 14:19:39 - DEBUG - Checking BUD to BRS
# 2023-03-11 14:19:42 - DEBUG - no routes found!
# 2023-03-11 14:19:42 - DEBUG - Checking BUD to CWL
# 2023-03-11 14:19:43 - DEBUG - no routes found!
# 2023-03-11 14:19:43 - DEBUG - Checking BUD to DSA
# 2023-03-11 14:19:44 - DEBUG - no routes found!
# 2023-03-11 14:19:44 - DEBUG - Checking BUD to EMA
# 2023-03-11 14:19:45 - DEBUG - Result dataframe len: 57
# 2023-03-11 14:19:45 - DEBUG - Checking BUD to EDI
# 2023-03-11 14:19:48 - DEBUG - no routes found!
# 2023-03-11 14:19:48 - DEBUG - Checking BUD to EXT
# 2023-03-11 14:19:50 - DEBUG - no routes found!
# 2023-03-11 14:19:50 - DEBUG - Checking BUD to GLA
# 2023-03-11 14:19:50 - DEBUG - no routes found!
# 2023-03-11 14:19:50 - DEBUG - Checking BUD to PIK
# 2023-03-11 14:19:51 - DEBUG - no routes found!
# 2023-03-11 14:19:51 - DEBUG - Checking BUD to HUY
# 2023-03-11 14:19:52 - DEBUG - no routes found!
# 2023-03-11 14:19:52 - DEBUG - Checking BUD to JER
# 2023-03-11 14:19:53 - DEBUG - no routes found!
# 2023-03-11 14:19:53 - DEBUG - Checking BUD to LBA
# 2023-03-11 14:19:59 - DEBUG - Result dataframe len: 29
# 2023-03-11 14:19:59 - DEBUG - Checking BUD to LPL
# 2023-03-11 14:20:02 - DEBUG - no routes found!
# 2023-03-11 14:20:02 - DEBUG - Checking BUD to LCY
# 2023-03-11 14:20:04 - DEBUG - no routes found!
# 2023-03-11 14:20:04 - DEBUG - Checking BUD to LGW
# 2023-03-11 14:20:07 - DEBUG - no routes found!
# 2023-03-11 14:20:07 - DEBUG - Checking BUD to LHR
# 2023-03-11 14:20:11 - DEBUG - Result dataframe len: 243
# 2023-03-11 14:20:11 - DEBUG - Checking BUD to LTN
# 2023-03-11 14:20:15 - DEBUG - no routes found!
# 2023-03-11 14:20:15 - DEBUG - Checking BUD to SEN
# 2023-03-11 14:20:17 - DEBUG - no routes found!
# 2023-03-11 14:20:17 - DEBUG - Checking BUD to STN
# 2023-03-11 14:20:20 - DEBUG - no routes found!
# 2023-03-11 14:20:20 - DEBUG - Checking BUD to MAN
# 2023-03-11 14:20:24 - DEBUG - no routes found!
# 2023-03-11 14:20:24 - DEBUG - Checking BUD to NCL
# 2023-03-11 14:20:26 - DEBUG - no routes found!
# 2023-03-11 14:20:26 - DEBUG - Checking BUD to SOU
# 2023-03-11 14:20:27 - DEBUG - no routes found!

# %%
len(final_result)
# Out:
# 5195

# %%
final_result.sort_values('PRICE', inplace=True)

# %%
final_result
# Out:
#                                                      ID   PRICE  FLY_DURATION  \
# 1417  0b7719be4c1000006844639b_0|19be0b774c140000cff...   15752          1.67
# 3029  0b7723b04c0c0000a5657e1a_0|23b00b774c0f0000d49...   16360          1.33
# 2365  0b7717594c1600009ae74c2c_0|17590b774c1a0000ffe...   16640          1.33
# 2916  0b7714fd4c2d000048ad8121_0|14fd0b774c3000007d7...   16899          1.25
# 1767  0b7718c54bf10000efd09189_0|18c50b774bf60000d8e...   16945          1.50
# ...                                                 ...     ...           ...
# 5191  0b770f644c004c0308f7030a_0|0b770f644c004c0308f...  245535          2.58
# 1416  0b770eec4c9e0000a1d21311_0|0eec0b774ca10000494...  246174          2.25
# 5193  0b770f644bf24bf6e51a02fe_0|0b770f644bf24bf6e51...  252443          2.58
# 5192  0b770f644bf24bf6e277c6e7_0|0b770f644bf24bf6e27...  252443          2.58
# 5194  0b770f644bf94bfc2cbeb03c_0|0b770f644bf94bfc2cb...  267886          2.58
#
#       RET_DURATION  TOTAL_DURATION                      ID_OUT  \
# 1417          1.67            3.33  0b7719be4c1000006844639b_0
# 3029          1.33            2.67  0b7723b04c0c0000a5657e1a_0
# 2365          1.33            2.67  0b7717594c1600009ae74c2c_0
# 2916          1.25            2.50  0b7714fd4c2d000048ad8121_0
# 1767          1.50            3.00  0b7718c54bf10000efd09189_0
# ...            ...             ...                         ...
# 5191          2.50            5.08  0b770f644c004c0308f7030a_0
# 1416          2.33            4.58  0b770eec4c9e0000a1d21311_0
# 5193          2.50            5.08  0b770f644bf24bf6e51a02fe_0
# 5192          2.50            5.08  0b770f644bf24bf6e277c6e7_0
# 5194          2.50            5.08  0b770f644bf94bfc2cbeb03c_0
#
#           DEP_DATE_OUT      ARR_DATE_OUT AIRLINE_OUT CITY_FROM_OUT  \
# 1417  2023-04-25 06:20  2023-04-25 09:00          W6      Budapest
# 3029  2023-04-21 15:10  2023-04-21 16:30          FR      Budapest
# 2365  2023-05-01 06:25  2023-05-01 07:45          W6      Budapest
# 2916  2023-05-24 08:20  2023-05-24 09:35          FR      Budapest
# 1767  2023-03-25 23:00  2023-03-26 00:30          FR      Budapest
# ...                ...               ...         ...           ...
# 5191  2023-04-09 21:05  2023-04-09 22:40          BA      Budapest
# 1416  2023-09-14 14:30  2023-09-14 17:45          W6      Budapest
# 5193  2023-03-26 21:05  2023-03-26 22:40          BA      Budapest
# 5192  2023-03-26 21:05  2023-03-26 22:40          BA      Budapest
# 5194  2023-04-02 21:05  2023-04-02 22:40          BA      Budapest
#
#        CITY_TO_OUT  FLIGHT_NO_OUT                     ID_BACK  \
# 1417  Thessaloniki           2447  19be0b774c140000cff6c89e_0
# 3029        Warsaw           1923  23b00b774c0f0000d490e487_0
# 2365     Podgorica           2231  17590b774c1a0000ffe0d01b_0
# 2916        Poznań           4271  14fd0b774c3000007d747e24_0
# 1767       Bologna           3827  18c50b774bf60000d8e040c2_0
# ...            ...            ...                         ...
# 5191        London            889  0b770f644c004c0308f7030a_1
# 1416     Santorini           2453  0eec0b774ca10000494d93d4_0
# 5193        London            889  0b770f644bf24bf6e51a02fe_1
# 5192        London            889  0b770f644bf24bf6e277c6e7_1
# 5194        London            889  0b770f644bf94bfc2cbeb03c_1
#
#          DEP_DATE_BACK     ARR_DATE_BACK AIRLINE_BACK CITY_FROM_BACK  \
# 1417  2023-04-29 09:45  2023-04-29 10:25           W6   Thessaloniki
# 3029  2023-04-24 21:10  2023-04-24 22:30           FR         Warsaw
# 2365  2023-05-05 14:10  2023-05-05 15:30           W6      Podgorica
# 2916  2023-05-27 05:55  2023-05-27 07:10           FR         Poznań
# 1767  2023-03-30 22:25  2023-03-30 23:55           FR        Bologna
# ...                ...               ...          ...            ...
# 5191  2023-04-12 14:00  2023-04-12 17:30           BA         London
# 1416  2023-09-17 22:05  2023-09-17 23:25           W6      Santorini
# 5193  2023-03-30 13:25  2023-03-30 16:55           BA         London
# 5192  2023-03-30 20:45  2023-03-31 00:15           BA         London
# 5194  2023-04-05 21:15  2023-04-06 00:45           BA         London
#
#      CITY_TO_BACK  FLIGHT_NO_BACK
# 1417     Budapest            2448
# 3029     Budapest            1922
# 2365     Budapest            2232
# 2916     Budapest            4272
# 1767     Budapest            3826
# ...           ...             ...
# 5191     Budapest             874
# 1416     Budapest            2454
# 5193     Budapest             874
# 5192     Budapest             870
# 5194     Budapest             870
#
# [5195 rows x 19 columns]

# %%
final_result.columns
# Out:
# Index(['ID', 'PRICE', 'FLY_DURATION', 'RET_DURATION', 'TOTAL_DURATION',
#        'ID_OUT', 'DEP_DATE_OUT', 'ARR_DATE_OUT', 'AIRLINE_OUT',
#        'CITY_FROM_OUT', 'CITY_TO_OUT', 'FLIGHT_NO_OUT', 'ID_BACK',
#        'DEP_DATE_BACK', 'ARR_DATE_BACK', 'AIRLINE_BACK', 'CITY_FROM_BACK',
#        'CITY_TO_BACK', 'FLIGHT_NO_BACK'],
#       dtype='object')

# %%
db_user = 'kebodev'
db_pass = 'SolarDhom1985+'
db_host = '95.138.193.102'
db_port = '3306'
database= 'flight'
connect_string = 'mysql+pymysql://' + db_user + ":" + db_pass + "@" + db_host + ":" + db_port + "/" + database

# %%
connection = create_engine(connect_string, pool_pre_ping=True, connect_args={'connect_timeout': 6000}).connect()

# %%
final_result.to_sql('FLIGHT_SEARCH_RESULT', connection, if_exists='append', index=False)
# Out:
# 5195
